# %%
import pandas as pd
df=pd.read_csv("phone_data.csv")
df.head()
# Out:
#    index            date  duration  item    month   network network_type
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile

# %%
df.shape
# Out:
# (830, 7)

# %%
df.count()
# Out:
# index           830
# date            830
# duration        830
# item            830
# month           830
# network         830
# network_type    830
# dtype: int64

# %%
a=df["duration"].max()
a
# Out:
# 10528.0

# %%
t=df["duration"].sum(axis=0)
t
# Out:
# 97777.35000000002

# %%
df.groupby("month")["index"].count()
# Out:
# month
# 2014-11    230
# 2014-12    157
# 2015-01    205
# 2015-02    137
# 2015-03    101
# Name: index, dtype: int64

# %%
df["network"].unique()
# Out:
# array(['data', 'Vodafone', 'Meteor', 'Tesco', 'Three', 'voicemail',
#        'landline', 'special', 'world'], dtype=object)

# %%
df.groupby("month").groups.keys()
# Out:
# dict_keys(['2014-11', '2014-12', '2015-01', '2015-02', '2015-03'])

# %%
df["network"].nunique()
# Out:
# 9

# %%
# df[df["month"]=='2014-11'].count()
a=df.groupby("month")["item"].count()
a['2014-11']
# Out:
# 230

# %%
len(df.groupby(['month']).groups['2014-11'])
# Out:
# 230

# %%
df.groupby("month").head(1)
# Out:
#      index             date  duration  item    month   network network_type
# 0        0   15/10/14 06:58    34.429  data  2014-11      data         data
# 228    228   13/11/14 06:58    34.429  data  2014-12      data         data
# 381    381   13/12/14 06:58    34.429  data  2015-01      data         data
# 577    577   13/01/15 06:58    34.429  data  2015-02      data         data
# 729    729  12/2/2015 20:15    69.000  call  2015-03  landline     landline

# %%
df.groupby("month").first()
# Out:
#          index             date  duration  item   network network_type
# month
# 2014-11      0   15/10/14 06:58    34.429  data      data         data
# 2014-12    228   13/11/14 06:58    34.429  data      data         data
# 2015-01    381   13/12/14 06:58    34.429  data      data         data
# 2015-02    577   13/01/15 06:58    34.429  data      data         data
# 2015-03    729  12/2/2015 20:15    69.000  call  landline     landline

# %%
df.groupby("month")['duration'].sum()
# Out:
# month
# 2014-11    26639.441
# 2014-12    14641.870
# 2015-01    18223.299
# 2015-02    15522.299
# 2015-03    22750.441
# Name: duration, dtype: float64

# %%
df.groupby("month")['date'].count()
# Out:
# month
# 2014-11    230
# 2014-12    157
# 2015-01    205
# 2015-02    137
# 2015-03    101
# Name: date, dtype: int64

# %%
df.groupby("network")["duration"].sum()
# Out:
# network
# Meteor        7233.00
# Tesco        13841.00
# Three        36551.00
# Vodafone     14770.00
# data          5164.35
# landline     18433.00
# special          3.00
# voicemail     1775.00
# world            7.00
# Name: duration, dtype: float64

# %%
df[df["item"]=='call'].groupby(['network'])['duration'].sum()
# Out:
# network
# Meteor        7200.0
# Tesco        13828.0
# Three        36464.0
# Vodafone     14621.0
# landline     18433.0
# voicemail     1775.0
# Name: duration, dtype: float64

# %%
df.groupby(["month","item"]).count()
# Out:
#               index  date  duration  network  network_type
# month   item
# 2014-11 call    107   107       107      107           107
#         data     29    29        29       29            29
#         sms      94    94        94       94            94
# 2014-12 call     79    79        79       79            79
#         data     30    30        30       30            30
#         sms      48    48        48       48            48
# 2015-01 call     88    88        88       88            88
#         data     31    31        31       31            31
#         sms      86    86        86       86            86
# 2015-02 call     67    67        67       67            67
#         data     31    31        31       31            31
#         sms      39    39        39       39            39
# 2015-03 call     47    47        47       47            47
#         data     29    29        29       29            29
#         sms      25    25        25       25            25

# %%
df.groupby(["month","item"])["date"].count()
# Out:
# month    item
# 2014-11  call    107
#          data     29
#          sms      94
# 2014-12  call     79
#          data     30
#          sms      48
# 2015-01  call     88
#          data     31
#          sms      86
# 2015-02  call     67
#          data     31
#          sms      39
# 2015-03  call     47
#          data     29
#          sms      25
# Name: date, dtype: int64

# %%
df.groupby(["month","item"])['network_type'].count()
# Out:
# month    item
# 2014-11  call    107
#          data     29
#          sms      94
# 2014-12  call     79
#          data     30
#          sms      48
# 2015-01  call     88
#          data     31
#          sms      86
# 2015-02  call     67
#          data     31
#          sms      39
# 2015-03  call     47
#          data     29
#          sms      25
# Name: network_type, dtype: int64

# %%
df.groupby(["month","network_type"])["date"].count()
# Out:
# month    network_type
# 2014-11  data             29
#          landline          5
#          mobile          189
#          special           1
#          voicemail         6
# 2014-12  data             30
#          landline          7
#          mobile          108
#          voicemail         8
#          world             4
# 2015-01  data             31
#          landline         11
#          mobile          160
#          voicemail         3
# 2015-02  data             31
#          landline          8
#          mobile           90
#          special           2
#          voicemail         6
# 2015-03  data             29
#          landline         11
#          mobile           54
#          voicemail         4
#          world             3
# Name: date, dtype: int64

# %%
df.groupby("month")["duration"].sum()
# Out:
# month
# 2014-11    26639.441
# 2014-12    14641.870
# 2015-01    18223.299
# 2015-02    15522.299
# 2015-03    22750.441
# Name: duration, dtype: float64

# %%
df.groupby('month', as_index=False).agg({"duration": "sum"})
# Out:
#      month   duration
# 0  2014-11  26639.441
# 1  2014-12  14641.870
# 2  2015-01  18223.299
# 3  2015-02  15522.299
# 4  2015-03  22750.441

# %%
df.groupby('month', as_index=False).agg({"duration": ["sum","mean"]})
# Out:
#      month   duration
#                   sum        mean
# 0  2014-11  26639.441  115.823657
# 1  2014-12  14641.870   93.260318
# 2  2015-01  18223.299   88.894141
# 3  2015-02  15522.299  113.301453
# 4  2015-03  22750.441  225.251891

# %%
df.groupby('month','network',as_index=False).agg({"duration", "network"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-ba1c405b7f5a> in <module>
# ----> 1 df.groupby('month','network', as_index=False).agg({"duration", "network"})
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7881         if level is None and by is None:
#    7882             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7883         axis = self._get_axis_number(axis)
#    7884         return groupby(
#    7885             self,
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named network for object type <class 'pandas.core.frame.DataFrame'>

# %%
df.groupby('month',as_index=False).agg({"duration":["sum","mean"], "network":["count"],"network_type":["first"]})
# Out:
#      month   duration             network network_type
#                   sum        mean   count        first
# 0  2014-11  26639.441  115.823657     230         data
# 1  2014-12  14641.870   93.260318     157         data
# 2  2015-01  18223.299   88.894141     205         data
# 3  2015-02  15522.299  113.301453     137         data
# 4  2015-03  22750.441  225.251891     101     landline

# %% [markdown]
# # merge datasets

# %%
from pandas import Series, DataFrame
import pandas as pd

ratings = pd.read_csv("rating_final.csv")
parking = pd.read_csv("chefmozparking.csv")


# Left merge: Keep everything from the left, drop things from the right (if they don't match)
left_merge = pd.merge(left=ratings, right=parking, on="placeID", how="left")
print (left_merge.head())

# Right merge: Keep everything from the right, drop things from the left (if they don't match)
right_merge = pd.merge(left=ratings, right=parking, on="placeID", how="right")
print (right_merge.head())

# Inner merge: Keep only data which are matched in left and right 
inner_merge = pd.merge(left=ratings, right=parking, on="placeID", how="inner")
print (inner_merge.head())

# Outer merge: Keep everything from both, Fill the unmatched data with NAN
outer_merge = pd.merge(left=ratings, right=parking, on="placeID", how="outer")
print (outer_merge.head())
# Out:
#   userID  placeID  rating  food_rating  service_rating parking_lot
# 0  U1077   135085       2            2               2      public
# 1  U1077   135038       2            2               1        none
# 2  U1077   132825       2            2               2        none
# 3  U1077   135060       1            2               2        none
# 4  U1068   135104       1            1               2         yes
#   userID  placeID  rating  food_rating  service_rating parking_lot
# 0  U1077   135085     2.0          2.0             2.0      public
# 1  U1108   135085     1.0          2.0             1.0      public
# 2  U1081   135085     1.0          2.0             1.0      public
# 3  U1056   135085     2.0          2.0             2.0      public
# 4  U1134   135085     2.0          1.0             2.0      public
#   userID  placeID  rating  food_rating  service_rating parking_lot
# 0  U1077   135085       2            2               2      public
# 1  U1108   135085       1            2               1      public
# 2  U1081   135085       1            2               1      public
# 3  U1056   135085       2            2               2      public
# 4  U1134   135085       2            1               2      public
#   userID  placeID  rating  food_rating  service_rating parking_lot
# 0  U1077   135085     2.0          2.0             2.0      public
# 1  U1108   135085     1.0          2.0             1.0      public
# 2  U1081   135085     1.0          2.0             1.0      public
# 3  U1056   135085     2.0          2.0             2.0      public
# 4  U1134   135085     2.0          1.0             2.0      public

# %%
ratings.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
parking.head()
# Out:
#    placeID parking_lot
# 0   135111      public
# 1   135110        none
# 2   135109        none
# 3   135108        none
# 4   135107        none

# %%
# pd.merge(left=ratings,right=parking,on="placeID",how="left")

# %%
pd.merge(left=ratings,right=parking,on="placeID",how="right")
# Out:
#      userID  placeID  rating  food_rating  service_rating parking_lot
# 0     U1077   135085     2.0          2.0             2.0      public
# 1     U1108   135085     1.0          2.0             1.0      public
# 2     U1081   135085     1.0          2.0             1.0      public
# 3     U1056   135085     2.0          2.0             2.0      public
# 4     U1134   135085     2.0          1.0             2.0      public
# ...     ...      ...     ...          ...             ...         ...
# 1728    NaN   132024     NaN          NaN             NaN      street
# 1729    NaN   132023     NaN          NaN             NaN         fee
# 1730    NaN   132023     NaN          NaN             NaN      public
# 1731    NaN   132012     NaN          NaN             NaN      public
# 1732    NaN   132012     NaN          NaN             NaN      street
#
# [1733 rows x 6 columns]

# %% [markdown]
# # labtest

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("share-of-population-who-never-drink-alcohol.csv")
df1=pd.read_csv("alcohol_share.csv")
df2=pd.read_csv("road-traffic-deaths-to-alcohol.csv")
df3=pd.read_csv("death-rates-from-alcohol-use-disorders.csv")
# df.head()

# %%
df1.head()
# Out:
#                 Entity Code  Year  Beer (% of total alcohol consumption)  \
# 0              Albania  ALB  2010                                   31.8
# 1              Algeria  DZA  2010                                   62.6
# 2              Andorra  AND  2010                                   34.6
# 3               Angola  AGO  2010                                   64.3
# 4  Antigua and Barbuda  ATG  2010                                   36.4
#
#    Wine (% total alcohol consumption)  Spirits (% total alcohol consumption)  \
# 0                                19.8                                   48.4
# 1                                35.5                                    0.0
# 2                                45.3                                   20.1
# 3                                13.7                                   17.4
# 4                                16.4                                   47.0
#
#                        Region
# 0       Europe & Central Asia
# 1  Middle East & North Africa
# 2       Europe & Central Asia
# 3          Sub-Saharan Africa
# 4   Latin America & Caribbean

# %%
# df2.head()

# %%
# df3.head()

# %%
df1["Region"].unique()
# Out:
# array(['Europe & Central Asia', 'Middle East & North Africa',
#        'Sub-Saharan Africa', 'Latin America & Caribbean',
#        'East Asia & Pacific', 'South Asia', 'North America'], dtype=object)

# %%
df1["Beer (% of total alcohol consumption)"].mean()
# Out:
# 41.71173184357543

# %%
df1["Wine (% total alcohol consumption)"].mean()
# Out:
# 14.567039106145257

# %%
df1["Spirits (% total alcohol consumption)"].mean()
# Out:
# 32.42960893854748

# %%
df1.groupby("Region")["Beer (% of total alcohol consumption)","Wine (% total alcohol consumption)","Spirits (% total alcohol consumption)"].mean().mean()
# Out:
# Beer (% of total alcohol consumption)    43.550038
# Wine (% total alcohol consumption)       12.734183
# Spirits (% total alcohol consumption)    36.999109
# dtype: float64

# %%
df1.groupby("Region").sum().max()
# Out:
# Year                                     98490.0
# Beer (% of total alcohol consumption)     1802.3
# Wine (% total alcohol consumption)        1292.0
# Spirits (% total alcohol consumption)     1697.4
# dtype: float64

# %%
# df1.groupby(["Region","Beer (% of total alcohol consumption)"],as_index=False).max()
# df1.sort_values("Beer (% of total alcohol consumption)",ascending=False).groupby("Region").max()

# %%
a=df1.groupby(["Region"],as_index=False)["Beer (% of total alcohol consumption)"].sum()

a[a["Beer (% of total alcohol consumption)"]==a["Beer (% of total alcohol consumption)"].max()]["Region"]
# Out:
#                        Region  Beer (% of total alcohol consumption)
# 0         East Asia & Pacific                                 1453.2
# 1       Europe & Central Asia                                 1802.3
# 2   Latin America & Caribbean                                 1491.5
# 3  Middle East & North Africa                                  721.1
# 4               North America                                  101.2
# 5                  South Asia                                  167.5
# 6          Sub-Saharan Africa                                 1729.6

# %%
a=df1.groupby("Region",as_index=False)["Beer (% of total alcohol consumption)","Wine (% total alcohol consumption)","Spirits (% total alcohol consumption)"].mean()
a
# Out:
#                        Region  Beer (% of total alcohol consumption)  \
# 0         East Asia & Pacific                              51.900000
# 1       Europe & Central Asia                              36.781633
# 2   Latin America & Caribbean                              45.196970
# 3  Middle East & North Africa                              40.061111
# 4               North America                              50.600000
# 5                  South Asia                              41.875000
# 6          Sub-Saharan Africa                              38.435556
#
#    Wine (% total alcohol consumption)  Spirits (% total alcohol consumption)
# 0                           10.246429                              33.646429
# 1                           26.367347                              34.640816
# 2                            8.839394                              45.384848
# 3                           13.805556                              45.855556
# 4                           19.650000                              29.750000
# 5                            0.275000                              57.425000
# 6                            9.955556                              12.291111

# %%
x1=a.iloc[0,1:4].values
x2=a.iloc[1,1:4].values
x3=a.iloc[2,1:4].values
x4=a.iloc[3,1:4].values
x5=a.iloc[4,1:4].values
x6=a.iloc[5,1:4].values
x7=a.iloc[6,1:4].values

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(8,8))
ax1=fig.add_subplot(4,2,1)
ax2=fig.add_subplot(4,2,2)
ax3=fig.add_subplot(4,2,3)
ax4=fig.add_subplot(4,2,4)
ax5=fig.add_subplot(4,2,5)
ax6=fig.add_subplot(4,2,6)
ax7=fig.add_subplot(4,2,7)

ax1.pie(x1,autopct="%1.f%%")
# ax1.set_figheight(15)
ax2.pie(x2,autopct="%1.1f%%")
ax3.pie(x3,autopct="%1.1f%%")
ax4.pie(x4,autopct="%1.1f%%")
ax5.pie(x5,autopct="%1.1f%%")
ax6.pie(x6,autopct="%1.1f%%")
ax7.pie(x7,autopct="%1.1f%%")
plt.tight_layout()
plt.axis("equal")
plt.show()

# %%
df2.head()
# Out:
#       Entity Code  Year  \
# 0    Albania  ALB  2013
# 1    Andorra  AND  2013
# 2  Argentina  ARG  2013
# 3    Armenia  ARM  2013
# 4  Australia  AUS  2013
#
#    Indicator:Attribution of road traffic deaths to alcohol (%) (%)
# 0                                                6.1
# 1                                                0.0
# 2                                               27.0
# 3                                                1.9
# 4                                               30.0

# %%
d=df2.sort_values("Indicator:Attribution of road traffic deaths to alcohol (%) (%)",ascending=False).head(5)
d
# Out:
#               Entity Code  Year  \
# 63             Palau  PLW  2013
# 51  Marshall Islands  MHL  2013
# 73        Seychelles  SYC  2013
# 79      South Africa  ZAF  2013
# 64  Papua New Guinea  PNG  2013
#
#     Indicator:Attribution of road traffic deaths to alcohol (%) (%)
# 63                                              100.0
# 51                                              100.0
# 73                                               60.0
# 79                                               57.5
# 64                                               56.0

# %%
x=d.iloc[:,0].values
y=d.iloc[:,3].values

# %%
plt.bar(x,y)
plt.xticks(rotation=60)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)

# %%
# df3["Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)"]
df3[df3["Entity"]=="Afghanistan"]["market"]
# Out:
#          Entity Code  Year  \
# 0   Afghanistan  AFG  1990
# 1   Afghanistan  AFG  1991
# 2   Afghanistan  AFG  1992
# 3   Afghanistan  AFG  1993
# 4   Afghanistan  AFG  1994
# 5   Afghanistan  AFG  1995
# 6   Afghanistan  AFG  1996
# 7   Afghanistan  AFG  1997
# 8   Afghanistan  AFG  1998
# 9   Afghanistan  AFG  1999
# 10  Afghanistan  AFG  2000
# 11  Afghanistan  AFG  2001
# 12  Afghanistan  AFG  2002
# 13  Afghanistan  AFG  2003
# 14  Afghanistan  AFG  2004
# 15  Afghanistan  AFG  2005
# 16  Afghanistan  AFG  2006
# 17  Afghanistan  AFG  2007
# 18  Afghanistan  AFG  2008
# 19  Afghanistan  AFG  2009
# 20  Afghanistan  AFG  2010
# 21  Afghanistan  AFG  2011
# 22  Afghanistan  AFG  2012
# 23  Afghanistan  AFG  2013
# 24  Afghanistan  AFG  2014
# 25  Afghanistan  AFG  2015
# 26  Afghanistan  AFG  2016
#
#     Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)
# 0                                            0.733952
# 1                                            0.738027
# 2                                            0.743333
# 3                                            0.751269
# 4                                            0.760493
# 5                                            0.764488
# 6                                            0.765997
# 7                                            0.766809
# 8                                            0.766500
# 9                                            0.769630
# 10                                           0.775724
# 11                                           0.784650
# 12                                           0.787920
# 13                                           0.792577
# 14                                           0.797375
# 15                                           0.799561
# 16                                           0.799163
# 17                                           0.795967
# 18                                           0.793495
# 19                                           0.788030
# 20                                           0.782419
# 21                                           0.778248
# 22                                           0.774798
# 23                                           0.773680
# 24                                           0.772648
# 25                                           0.772360
# 26                                           0.772183

# %%
df3.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)
# 0                                           0.733952
# 1                                           0.738027
# 2                                           0.743333
# 3                                           0.751269
# 4                                           0.760493

# %%
# df3[df3['Year']>df3['Year']+1]
df3[(df3.iloc[0,3] > df3.iloc[1,3]) & (df2.iloc[1,3] > df3.iloc[2,3])]

# df3.iloc[0,3]>df3.iloc[1:,3]
# for i in d3.iterrows():
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 6126    False
# 6127    False
# 6128    False
# 6129    False
# 6130    False
# 6131    False
# 6132    False
# 6133    False
# 6134    False
# 6135    False
# 6136    False
# 6137    False
# 6138    False
# 6139    False
# 6140    False
# 6141    False
# 6142    False
# 6143    False
# 6144    False
# 6145    False
# 6146    False
# 6147    False
# 6148    False
# 6149    False
# 6150    False
# 6151    False
# 6152    False
# 6153    False
# 6154    False
# 6155    False
# Name: Year, Length: 6156, dtype: bool

# %%
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2010
# 1      Albania  ALB  2010
# 2      Algeria  DZA  2010
# 3      Andorra  AND  2010
# 4       Angola  AGO  2010
#
#    Indicator:Alcohol, abstainers lifetime (%) - Sex:Both sexes (%)
# 0                                               92.5
# 1                                               24.4
# 2                                               81.3
# 3                                               12.6
# 4                                               52.0

# %%
df2.head()
# Out:
#       Entity Code  Year  \
# 0    Albania  ALB  2013
# 1    Andorra  AND  2013
# 2  Argentina  ARG  2013
# 3    Armenia  ARM  2013
# 4  Australia  AUS  2013
#
#    Indicator:Attribution of road traffic deaths to alcohol (%) (%)
# 0                                                6.1
# 1                                                0.0
# 2                                               27.0
# 3                                                1.9
# 4                                               30.0

# %%
df1
# Out:
#                   Entity Code  Year  Beer (% of total alcohol consumption)  \
# 0                Albania  ALB  2010                                   31.8
# 1                Algeria  DZA  2010                                   62.6
# 2                Andorra  AND  2010                                   34.6
# 3                 Angola  AGO  2010                                   64.3
# 4    Antigua and Barbuda  ATG  2010                                   36.4
# ..                   ...  ...   ...                                    ...
# 174            Venezuela  VEN  2010                                   75.6
# 175              Vietnam  VNM  2010                                   97.3
# 176                Yemen  YEM  2010                                  100.0
# 177               Zambia  ZMB  2010                                   22.7
# 178             Zimbabwe  ZWE  2010                                   23.7
#
#      Wine (% total alcohol consumption)  \
# 0                                  19.8
# 1                                  35.5
# 2                                  45.3
# 3                                  13.7
# 4                                  16.4
# ..                                  ...
# 174                                 0.8
# 175                                 0.6
# 176                                 0.0
# 177                                 2.9
# 178                                 1.7
#
#      Spirits (% total alcohol consumption)                      Region
# 0                                     48.4       Europe & Central Asia
# 1                                      0.0  Middle East & North Africa
# 2                                     20.1       Europe & Central Asia
# 3                                     17.4          Sub-Saharan Africa
# 4                                     47.0   Latin America & Caribbean
# ..                                     ...                         ...
# 174                                   23.4   Latin America & Caribbean
# 175                                    2.1         East Asia & Pacific
# 176                                    0.0  Middle East & North Africa
# 177                                   13.6          Sub-Saharan Africa
# 178                                    6.8          Sub-Saharan Africa
#
# [179 rows x 7 columns]

# %%
x=pd.merge(left=df3,right=df1,on="Entity",how="left")
x
# x.groupby("Region")["Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)"].mean()
# Out:
#            Entity Code_x  Year_x  \
# 0     Afghanistan    AFG    1990
# 1     Afghanistan    AFG    1991
# 2     Afghanistan    AFG    1992
# 3     Afghanistan    AFG    1993
# 4     Afghanistan    AFG    1994
# 5     Afghanistan    AFG    1995
# 6     Afghanistan    AFG    1996
# 7     Afghanistan    AFG    1997
# 8     Afghanistan    AFG    1998
# 9     Afghanistan    AFG    1999
# 10    Afghanistan    AFG    2000
# 11    Afghanistan    AFG    2001
# 12    Afghanistan    AFG    2002
# 13    Afghanistan    AFG    2003
# 14    Afghanistan    AFG    2004
# 15    Afghanistan    AFG    2005
# 16    Afghanistan    AFG    2006
# 17    Afghanistan    AFG    2007
# 18    Afghanistan    AFG    2008
# 19    Afghanistan    AFG    2009
# 20    Afghanistan    AFG    2010
# 21    Afghanistan    AFG    2011
# 22    Afghanistan    AFG    2012
# 23    Afghanistan    AFG    2013
# 24    Afghanistan    AFG    2014
# 25    Afghanistan    AFG    2015
# 26    Afghanistan    AFG    2016
# 27        Albania    ALB    1990
# 28        Albania    ALB    1991
# 29        Albania    ALB    1992
# ...           ...    ...     ...
# 6126       Zambia    ZMB    2014
# 6127       Zambia    ZMB    2015
# 6128       Zambia    ZMB    2016
# 6129     Zimbabwe    ZWE    1990
# 6130     Zimbabwe    ZWE    1991
# 6131     Zimbabwe    ZWE    1992
# 6132     Zimbabwe    ZWE    1993
# 6133     Zimbabwe    ZWE    1994
# 6134     Zimbabwe    ZWE    1995
# 6135     Zimbabwe    ZWE    1996
# 6136     Zimbabwe    ZWE    1997
# 6137     Zimbabwe    ZWE    1998
# 6138     Zimbabwe    ZWE    1999
# 6139     Zimbabwe    ZWE    2000
# 6140     Zimbabwe    ZWE    2001
# 6141     Zimbabwe    ZWE    2002
# 6142     Zimbabwe    ZWE    2003
# 6143     Zimbabwe    ZWE    2004
# 6144     Zimbabwe    ZWE    2005
# 6145     Zimbabwe    ZWE    2006
# 6146     Zimbabwe    ZWE    2007
# 6147     Zimbabwe    ZWE    2008
# 6148     Zimbabwe    ZWE    2009
# 6149     Zimbabwe    ZWE    2010
# 6150     Zimbabwe    ZWE    2011
# 6151     Zimbabwe    ZWE    2012
# 6152     Zimbabwe    ZWE    2013
# 6153     Zimbabwe    ZWE    2014
# 6154     Zimbabwe    ZWE    2015
# 6155     Zimbabwe    ZWE    2016
#
#       Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)  \
# 0                                              0.733952
# 1                                              0.738027
# 2                                              0.743333
# 3                                              0.751269
# 4                                              0.760493
# 5                                              0.764488
# 6                                              0.765997
# 7                                              0.766809
# 8                                              0.766500
# 9                                              0.769630
# 10                                             0.775724
# 11                                             0.784650
# 12                                             0.787920
# 13                                             0.792577
# 14                                             0.797375
# 15                                             0.799561
# 16                                             0.799163
# 17                                             0.795967
# 18                                             0.793495
# 19                                             0.788030
# 20                                             0.782419
# 21                                             0.778248
# 22                                             0.774798
# 23                                             0.773680
# 24                                             0.772648
# 25                                             0.772360
# 26                                             0.772183
# 27                                             0.363830
# 28                                             0.372260
# 29                                             0.377130
# ...                                                 ...
# 6126                                           3.520942
# 6127                                           3.513072
# 6128                                           3.519717
# 6129                                           1.575534
# 6130                                           1.276923
# 6131                                           1.149488
# 6132                                           1.048685
# 6133                                           0.981628
# 6134                                           0.958922
# 6135                                           1.031273
# 6136                                           1.143704
# 6137                                           1.324255
# 6138                                           1.609939
# 6139                                           2.045819
# 6140                                           2.395663
# 6141                                           2.912066
# 6142                                           3.353263
# 6143                                           3.861240
# 6144                                           4.237684
# 6145                                           4.477811
# 6146                                           4.677172
# 6147                                           4.532125
# 6148                                           4.420714
# 6149                                           4.304477
# 6150                                           4.186731
# 6151                                           4.091793
# 6152                                           4.038485
# 6153                                           4.030317
# 6154                                           4.021801
# 6155                                           4.018045
#
#      Code_y  Year_y  Beer (% of total alcohol consumption)  \
# 0       NaN     NaN                                    NaN
# 1       NaN     NaN                                    NaN
# 2       NaN     NaN                                    NaN
# 3       NaN     NaN                                    NaN
# 4       NaN     NaN                                    NaN
# 5       NaN     NaN                                    NaN
# 6       NaN     NaN                                    NaN
# 7       NaN     NaN                                    NaN
# 8       NaN     NaN                                    NaN
# 9       NaN     NaN                                    NaN
# 10      NaN     NaN                                    NaN
# 11      NaN     NaN                                    NaN
# 12      NaN     NaN                                    NaN
# 13      NaN     NaN                                    NaN
# 14      NaN     NaN                                    NaN
# 15      NaN     NaN                                    NaN
# 16      NaN     NaN                                    NaN
# 17      NaN     NaN                                    NaN
# 18      NaN     NaN                                    NaN
# 19      NaN     NaN                                    NaN
# 20      NaN     NaN                                    NaN
# 21      NaN     NaN                                    NaN
# 22      NaN     NaN                                    NaN
# 23      NaN     NaN                                    NaN
# 24      NaN     NaN                                    NaN
# 25      NaN     NaN                                    NaN
# 26      NaN     NaN                                    NaN
# 27      ALB  2010.0                                   31.8
# 28      ALB  2010.0                                   31.8
# 29      ALB  2010.0                                   31.8
# ...     ...     ...                                    ...
# 6126    ZMB  2010.0                                   22.7
# 6127    ZMB  2010.0                                   22.7
# 6128    ZMB  2010.0                                   22.7
# 6129    ZWE  2010.0                                   23.7
# 6130    ZWE  2010.0                                   23.7
# 6131    ZWE  2010.0                                   23.7
# 6132    ZWE  2010.0                                   23.7
# 6133    ZWE  2010.0                                   23.7
# 6134    ZWE  2010.0                                   23.7
# 6135    ZWE  2010.0                                   23.7
# 6136    ZWE  2010.0                                   23.7
# 6137    ZWE  2010.0                                   23.7
# 6138    ZWE  2010.0                                   23.7
# 6139    ZWE  2010.0                                   23.7
# 6140    ZWE  2010.0                                   23.7
# 6141    ZWE  2010.0                                   23.7
# 6142    ZWE  2010.0                                   23.7
# 6143    ZWE  2010.0                                   23.7
# 6144    ZWE  2010.0                                   23.7
# 6145    ZWE  2010.0                                   23.7
# 6146    ZWE  2010.0                                   23.7
# 6147    ZWE  2010.0                                   23.7
# 6148    ZWE  2010.0                                   23.7
# 6149    ZWE  2010.0                                   23.7
# 6150    ZWE  2010.0                                   23.7
# 6151    ZWE  2010.0                                   23.7
# 6152    ZWE  2010.0                                   23.7
# 6153    ZWE  2010.0                                   23.7
# 6154    ZWE  2010.0                                   23.7
# 6155    ZWE  2010.0                                   23.7
#
#       Wine (% total alcohol consumption)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                  19.8
# 28                                  19.8
# 29                                  19.8
# ...                                  ...
# 6126                                 2.9
# 6127                                 2.9
# 6128                                 2.9
# 6129                                 1.7
# 6130                                 1.7
# 6131                                 1.7
# 6132                                 1.7
# 6133                                 1.7
# 6134                                 1.7
# 6135                                 1.7
# 6136                                 1.7
# 6137                                 1.7
# 6138                                 1.7
# 6139                                 1.7
# 6140                                 1.7
# 6141                                 1.7
# 6142                                 1.7
# 6143                                 1.7
# 6144                                 1.7
# 6145                                 1.7
# 6146                                 1.7
# 6147                                 1.7
# 6148                                 1.7
# 6149                                 1.7
# 6150                                 1.7
# 6151                                 1.7
# 6152                                 1.7
# 6153                                 1.7
# 6154                                 1.7
# 6155                                 1.7
#
#       Spirits (% total alcohol consumption)                 Region
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
# 5                                       NaN                    NaN
# 6                                       NaN                    NaN
# 7                                       NaN                    NaN
# 8                                       NaN                    NaN
# 9                                       NaN                    NaN
# 10                                      NaN                    NaN
# 11                                      NaN                    NaN
# 12                                      NaN                    NaN
# 13                                      NaN                    NaN
# 14                                      NaN                    NaN
# 15                                      NaN                    NaN
# 16                                      NaN                    NaN
# 17                                      NaN                    NaN
# 18                                      NaN                    NaN
# 19                                      NaN                    NaN
# 20                                      NaN                    NaN
# 21                                      NaN                    NaN
# 22                                      NaN                    NaN
# 23                                      NaN                    NaN
# 24                                      NaN                    NaN
# 25                                      NaN                    NaN
# 26                                      NaN                    NaN
# 27                                     48.4  Europe & Central Asia
# 28                                     48.4  Europe & Central Asia
# 29                                     48.4  Europe & Central Asia
# ...                                     ...                    ...
# 6126                                   13.6     Sub-Saharan Africa
# 6127                                   13.6     Sub-Saharan Africa
# 6128                                   13.6     Sub-Saharan Africa
# 6129                                    6.8     Sub-Saharan Africa
# 6130                                    6.8     Sub-Saharan Africa
# 6131                                    6.8     Sub-Saharan Africa
# 6132                                    6.8     Sub-Saharan Africa
# 6133                                    6.8     Sub-Saharan Africa
# 6134                                    6.8     Sub-Saharan Africa
# 6135                                    6.8     Sub-Saharan Africa
# 6136                                    6.8     Sub-Saharan Africa
# 6137                                    6.8     Sub-Saharan Africa
# 6138                                    6.8     Sub-Saharan Africa
# 6139                                    6.8     Sub-Saharan Africa
# 6140                                    6.8     Sub-Saharan Africa
# 6141                                    6.8     Sub-Saharan Africa
# 6142                                    6.8     Sub-Saharan Africa
# 6143                                    6.8     Sub-Saharan Africa
# 6144                                    6.8     Sub-Saharan Africa
# 6145                                    6.8     Sub-Saharan Africa
# 6146                                    6.8     Sub-Saharan Africa
# 6147                                    6.8     Sub-Saharan Africa
# 6148                                    6.8     Sub-Saharan Africa
# 6149                                    6.8     Sub-Saharan Africa
# 6150                                    6.8     Sub-Saharan Africa
# 6151                                    6.8     Sub-Saharan Africa
# 6152                                    6.8     Sub-Saharan Africa
# 6153                                    6.8     Sub-Saharan Africa
# 6154                                    6.8     Sub-Saharan Africa
# 6155                                    6.8     Sub-Saharan Africa
#
# [6156 rows x 10 columns]

# %%
y=pd.merge(left=df1,right=df3,on="Entity",how="left")
y.groupby("Region")["Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)"].mean()
# Out:
# Region
# East Asia & Pacific           1.553385
# Europe & Central Asia         5.050223
# Latin America & Caribbean     4.126055
# Middle East & North Africa    0.525874
# North America                 2.402441
# South Asia                    1.910683
# Sub-Saharan Africa            2.224757
# Name: Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000), dtype: float64

# %%
z=pd.merge(left=df3,right=df1,on="Entity",how="right")

z.groupby("Region")["Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)"].mean()
# Out:
# Region
# East Asia & Pacific           1.553385
# Europe & Central Asia         5.050223
# Latin America & Caribbean     4.126055
# Middle East & North Africa    0.525874
# North America                 2.402441
# South Asia                    1.910683
# Sub-Saharan Africa            2.224757
# Name: Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000), dtype: float64

# %%
pd.to_csv(z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-1622897bb537> in <module>()
# ----> 1 pd.to_csv(z)
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
abc=z.to_csv(r'export_dataframe.csv')

# %%
abc
# Out:
# ',Entity,Code_x,Year_x,"Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)",Code_y,Year_y,Beer (% of total alcohol consumption),Wine (% total alcohol consumption),Spirits (% total alcohol consumption),Region\n0,Albania,ALB,1990.0,0.363830384,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n1,Albania,ALB,1991.0,0.37226039299999997,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n2,Albania,ALB,1992.0,0.37712988,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n3,Albania,ALB,1993.0,0.391380551,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n4,Albania,ALB,1994.0,0.411255705,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n5,Albania,ALB,1995.0,0.422601104,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n6,Albania,ALB,1996.0,0.423431335,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n7,Albania,ALB,1997.0,0.426500627,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n8,Albania,ALB,1998.0,0.439857202,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n9,Albania,ALB,1999.0,0.456959509,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n10,Albania,ALB,2000.0,0.46035210600000004,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n11,Albania,ALB,2001.0,0.481329478,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n12,Albania,ALB,2002.0,0.48866542700000004,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n13,Albania,ALB,2003.0,0.49808155200000004,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n14,Albania,ALB,2004.0,0.504992641,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n15,Albania,ALB,2005.0,0.525541559,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n16,Albania,ALB,2006.0,0.5388822879999999,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n17,Albania,ALB,2007.0,0.555686235,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n18,Albania,ALB,2008.0,0.560453729,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n19,Albania,ALB,2009.0,0.53453236,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n20,Albania,ALB,2010.0,0.52840953,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n21,Albania,ALB,2011.0,0.520739473,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n22,Albania,ALB,2012.0,0.513747445,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n23,Albania,ALB,2013.0,0.507498048,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n24,Albania,ALB,2014.0,0.501931714,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n25,Albania,ALB,2015.0,0.49715508,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n26,Albania,ALB,2016.0,0.49274598299999994,ALB,2010,31.8,19.8,48.4,Europe & Central Asia\n27,Algeria,DZA,1990.0,0.339649605,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n28,Algeria,DZA,1991.0,0.33586875200000005,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n29,Algeria,DZA,1992.0,0.33462437100000003,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n30,Algeria,DZA,1993.0,0.333449657,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n31,Algeria,DZA,1994.0,0.331951395,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n32,Algeria,DZA,1995.0,0.32949719,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n33,Algeria,DZA,1996.0,0.328438725,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n34,Algeria,DZA,1997.0,0.32670594,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n35,Algeria,DZA,1998.0,0.323640726,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n36,Algeria,DZA,1999.0,0.325875469,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n37,Algeria,DZA,2000.0,0.326760705,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n38,Algeria,DZA,2001.0,0.32919959,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n39,Algeria,DZA,2002.0,0.330260463,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n40,Algeria,DZA,2003.0,0.33035121100000003,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n41,Algeria,DZA,2004.0,0.329501387,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n42,Algeria,DZA,2005.0,0.327266406,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n43,Algeria,DZA,2006.0,0.325336398,DZA,2010,62.6,35.5,0.0,Middle East & North Africa\n44,Algeria,DZA,2007.0,0.323211356,DZA,2010,62.6,35.5,0.0,Midd ...

# %%
df1
# Out:
#                      Entity Code  Year  Beer (% of total alcohol consumption)  \
# 0                   Albania  ALB  2010                                   31.8
# 1                   Algeria  DZA  2010                                   62.6
# 2                   Andorra  AND  2010                                   34.6
# 3                    Angola  AGO  2010                                   64.3
# 4       Antigua and Barbuda  ATG  2010                                   36.4
# 5                 Argentina  ARG  2010                                   40.7
# 6                   Armenia  ARM  2010                                    9.7
# 7                 Australia  AUS  2010                                   44.0
# 8                   Austria  AUT  2010                                   50.4
# 9                Azerbaijan  AZE  2010                                   28.7
# 10                  Bahamas  BHS  2010                                   34.0
# 11                  Bahrain  BHR  2010                                   36.6
# 12                 Barbados  BRB  2010                                   39.7
# 13                  Belarus  BLR  2010                                   17.3
# 14                  Belgium  BEL  2010                                   49.2
# 15                   Belize  BLZ  2010                                   67.6
# 16                    Benin  BEN  2010                                   54.6
# 17                   Bhutan  BTN  2010                                  100.0
# 18                  Bolivia  BOL  2010                                   76.8
# 19   Bosnia and Herzegovina  BIH  2010                                   29.1
# 20                 Botswana  BWA  2010                                   56.0
# 21                   Brazil  BRA  2010                                   59.6
# 22                   Brunei  BRN  2010                                   89.8
# 23                 Bulgaria  BGR  2010                                   39.3
# 24             Burkina Faso  BFA  2010                                   10.0
# 25                  Burundi  BDI  2010                                   24.5
# 26                 Cambodia  KHM  2010                                   45.7
# 27                 Cameroon  CMR  2010                                   44.4
# 28                   Canada  CAN  2010                                   51.2
# 29               Cape Verde  CPV  2010                                   63.0
# ..                      ...  ...   ...                                    ...
# 149                   Sudan  SDN  2010                                    8.0
# 150                Suriname  SUR  2010                                   40.0
# 151               Swaziland  SWZ  2010                                   33.6
# 152                  Sweden  SWE  2010                                   37.0
# 153             Switzerland  CHE  2010                                   31.8
# 154                   Syria  SYR  2010                                    8.5
# 155              Tajikistan  TJK  2010                                   10.2
# 156                Tanzania  TZA  2010                                   11.0
# 157                Thailand  THA  2010                                   27.0
# 158                   Timor  TLS  2010                                    9.3
# 159                    Togo  TGO  2010                                   48.9
# 160                   Tonga  TON  2010                                   57.9
# 161     Trinidad and Tobago  TTO  2010                                   54.0
# 162                 Tunisia  TUN  2010                                   68.6
# 163                  Turkey  TUR  2010                                   63.6
# 164            Turkmenistan  TKM  2010                                   15.4
# 165                  Tuvalu  TUV  2010                                   10.0
# 166                  Uganda  UGA  2010                                    9.4
# 167                 Ukraine  UKR  2010                                   40.5
# 168    United Arab Emirates  ARE  2010                                   10.3
# 169          United Kingdom  GBR  2010                                   36.9
# 170           United States  USA  2010                                   50.0
# 171                 Uruguay  URY  2010                                   30.6
# 172              Uzbekistan  UZB  2010                                   18.3
# 173                 Vanuatu  VUT  2010                                   40.5
# 174               Venezuela  VEN  2010                                   75.6
# 175                 Vietnam  VNM  2010                                   97.3
# 176                   Yemen  YEM  2010                                  100.0
# 177                  Zambia  ZMB  2010                                   22.7
# 178                Zimbabwe  ZWE  2010                                   23.7
#
#      Wine (% total alcohol consumption)  \
# 0                                  19.8
# 1                                  35.5
# 2                                  45.3
# 3                                  13.7
# 4                                  16.4
# 5                                  48.0
# 6                                   5.3
# 7                                  36.7
# 8                                  35.5
# 9                                   7.6
# 10                                 14.6
# 11                                  6.3
# 12                                 10.2
# 13                                  5.2
# 14                                 36.3
# 15                                  2.0
# 16                                 21.7
# 17                                  0.0
# 18                                  3.8
# 19                                  3.2
# 20                                 11.8
# 21                                  4.0
# 22                                  2.3
# 23                                 16.5
# 24                                  3.0
# 25                                  0.0
# 26                                  0.8
# 27                                  1.2
# 28                                 22.0
# 29                                  7.3
# ..                                  ...
# 149                                 0.0
# 150                                 2.3
# 151                                 0.8
# 152                                46.6
# 153                                49.4
# 154                                27.9
# 155                                 1.1
# 156                                 0.2
# 157                                 0.4
# 158                                75.9
# 159                                26.9
# 160                                 7.6
# 161                                 2.0
# 162                                27.7
# 163                                 8.6
# 164                                26.1
# 165                                15.5
# 166                                 0.1
# 167                                 9.0
# 168                                 2.9
# 169                                33.8
# 170                                17.3
# 171                                59.9
# 172                                 6.3
# 173                                22.8
# 174                                 0.8
# 175                                 0.6
# 176                                 0.0
# 177                                 2.9
# 178                                 1.7
#
#      Spirits (% total alcohol consumption)                      Region
# 0                                     48.4       Europe & Central Asia
# 1                                      0.0  Middle East & North Africa
# 2                                     20.1       Europe & Central Asia
# 3                                     17.4          Sub-Saharan Africa
# 4                                     47.0   Latin America & Caribbean
# 5                                      5.5   Latin America & Caribbean
# 6                                     84.9       Europe & Central Asia
# 7                                     12.5         East Asia & Pacific
# 8                                     14.0       Europe & Central Asia
# 9                                     63.3       Europe & Central Asia
# 10                                    50.4   Latin America & Caribbean
# 11                                    57.0  Middle East & North Africa
# 12                                    49.3   Latin America & Caribbean
# 13                                    46.6       Europe & Central Asia
# 14                                    14.4       Europe & Central Asia
# 15                                    30.3   Latin America & Caribbean
# 16                                     7.2          Sub-Saharan Africa
# 17                                     0.0                  South Asia
# 18                                    19.3   Latin America & Caribbean
# 19                                    67.7       Europe & Central Asia
# 20                                    11.5          Sub-Saharan Africa
# 21                                    36.3   Latin America & Caribbean
# 22                                     7.2         East Asia & Pacific
# 23                                    44.1       Europe & Central Asia
# 24                                     3.1          Sub-Saharan Africa
# 25                                     0.1          Sub-Saharan Africa
# 26                                    53.5         East Asia & Pacific
# 27                                     0.2          Sub-Saharan Africa
# 28                                    26.8               North America
# 29                                    25.4          Sub-Saharan Africa
# ..                                     ...                         ...
# 149                                   13.5          Sub-Saharan Africa
# 150                                   57.2   Latin America & Caribbean
# 151                                    0.7          Sub-Saharan Africa
# 152                                   15.1       Europe & Central Asia
# 153                                   17.6       Europe & Central Asia
# 154                                   63.5  Middle East & North Africa
# 155                                   88.7       Europe & Central Asia
# 156                                    1.8          Sub-Saharan Africa
# 157                                   72.6         East Asia & Pacific
# 158                                   14.8         East Asia & Pacific
# 159                                    2.4          Sub-Saharan Africa
# 160                                   34.3         East Asia & Pacific
# 161                                   43.8   Latin America & Caribbean
# 162                                    3.7  Middle East & North Africa
# 163                                   27.9       Europe & Central Asia
# 164                                   58.4       Europe & Central Asia
# 165                                   74.5         East Asia & Pacific
# 166                                    1.9          Sub-Saharan Africa
# 167                                   48.0       Europe & Central Asia
# 168                                   86.7  Middle East & North Africa
# 169                                   21.8       Europe & Central Asia
# 170                                   32.7               North America
# 171                                    9.5   Latin America & Caribbean
# 172                                   75.4       Europe & Central Asia
# 173                                   36.7         East Asia & Pacific
# 174                                   23.4   Latin America & Caribbean
# 175                                    2.1         East Asia & Pacific
# 176                                    0.0  Middle East & North Africa
# 177                                   13.6          Sub-Saharan Africa
# 178                                    6.8          Sub-Saharan Africa
#
# [179 rows x 7 columns]

# %%
a = df1.iloc[:,3:6]

# %%
abc=df1.groupby("Region")[""].mean()
abc.to_csv()
